# %%
import pandas as pd
import numpy as np
import datetime as dt
import json
import os

# %%
def get_meta_files():
    death_fp = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv'
    confirmed_fp ='https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'
    location_fp = '/home/zhgao/covid19-forecast-hub/data-locations/locations.csv'
    deaths = pd.read_csv(death_fp)
    confirmed = pd.read_csv(confirmed_fp)
    location = pd.read_csv(location_fp)
    ts_features = [item for item in deaths.columns if item not in ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
           'Country_Region', 'Lat', 'Long_', 'Combined_Key', 'Population', 'Province/State', 'Country/Region', 'Long']]
    deaths = deaths.groupby('Province_State')[ts_features].sum()
    deaths = deaths.stack().reset_index().rename({'Province_State':'location_name','level_1':'target_end_date',0:'label'},axis=1)
    
    deaths['target_end_date'] = pd.to_datetime(deaths['target_end_date'])
    deaths_US = deaths.groupby('target_end_date')['label'].sum().reset_index()
    deaths_US['location_name'] = 'US'
    deaths = pd.concat([deaths, deaths_US], axis=0, ignore_index=True)
    deaths['week_label'] = deaths['label'] - deaths.groupby('location_name')['label'].shift(7)

    ts_features = [item for item in confirmed.columns if item not in ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Province_State',
           'Country_Region', 'Lat', 'Long_', 'Combined_Key', 'Population', 'Province/State', 'Country/Region', 'Long']]
    confirmed = confirmed.groupby('Province_State')[ts_features].sum()
    confirmed = confirmed.stack().reset_index().rename({'Province_State':'location_name','level_1':'target_end_date',0:'label'},axis=1)
    confirmed['target_end_date'] = pd.to_datetime(confirmed['target_end_date'])
    confirmed_US = confirmed.groupby('target_end_date')['label'].sum().reset_index()
    confirmed_US['location_name'] = 'US'
    confirmed = pd.concat([confirmed, confirmed_US], axis=0, ignore_index=True)
    confirmed['week_label'] = confirmed['label'] - confirmed.groupby('location_name')['label'].shift(7)
    return deaths, confirmed, location

# %%
def dump_results(LOAD_DIR='../CDC',FILE_NAME='2020-11-02-MSRA-DeepST.csv'):
    target_list = ['1 wk ahead cum death', '2 wk ahead cum death',
       '3 wk ahead cum death', '4 wk ahead cum death',
       '1 wk ahead inc death', '2 wk ahead inc death',
       '3 wk ahead inc death', '4 wk ahead inc death',
       '1 wk ahead inc case', '2 wk ahead inc case',
       '3 wk ahead inc case', '4 wk ahead inc case']
    state_list = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
       'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
       'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
       'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
       'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
       'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
       'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
       'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
       'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
       'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming', 'US']
    dump_dict = dict()
    confirmed['target_end_date'] = pd.to_datetime(confirmed['target_end_date'])
    deaths['target_end_date'] = pd.to_datetime(deaths['target_end_date'])

    forecast = pd.read_csv(os.path.join(LOAD_DIR, FILE_NAME))
    forecast['target_end_date'] = pd.to_datetime(forecast['target_end_date'])
    forecast = forecast[forecast.type=='point']
    forecast = forecast[forecast.target.isin(target_list)]
    START_DATE = pd.to_datetime(forecast['target_end_date'].sort_values().values[0]) - dt.timedelta(days=7)
    deaths_now = deaths[deaths['target_end_date']==START_DATE].rename({'week_label':'last_label'},axis=1)[['location_name','last_label']]
    confirmed_now = confirmed[confirmed['target_end_date']==START_DATE].rename({'week_label':'last_label'},axis=1)[['location_name','last_label']]    
    forecast = pd.merge(forecast, location[['location','location_name']], on=['location'], how='left')
    
    forecast = forecast[forecast.location_name.isin(state_list)]
    
    forecast_cum_deaths = forecast[forecast['target'].map(lambda x:x.endswith('cum death'))]
    forecast_inc_deaths = forecast[forecast['target'].map(lambda x:x.endswith('inc death'))]
    forecast_inc_confirmed = forecast[forecast['target'].map(lambda x:x.endswith('case'))]

    forecast_cum_deaths = pd.merge(forecast_cum_deaths,deaths,on=['location_name','target_end_date'],how='left')
    forecast_inc_deaths = pd.merge(forecast_inc_deaths,deaths,on=['location_name','target_end_date'],how='left')
    forecast_inc_confirmed = pd.merge(forecast_inc_confirmed,confirmed,on=['location_name','target_end_date'],how='left')

    forecast_inc_deaths = pd.merge(forecast_inc_deaths, deaths_now, on=['location_name'], how='left')
    forecast_inc_confirmed = pd.merge(forecast_inc_confirmed, confirmed_now, on=['location_name'], how='left')

        
    START_DATE = pd.to_datetime(forecast['target_end_date'].sort_values().values[0]) - dt.timedelta(days=14)
    deaths_now = deaths[deaths['target_end_date']==START_DATE].rename({'week_label':'last2_label'},axis=1)[['location_name','last2_label']]
    confirmed_now = confirmed[confirmed['target_end_date']==START_DATE].rename({'week_label':'last2_label'},axis=1)[['location_name','last2_label']]    

    forecast_inc_deaths = pd.merge(forecast_inc_deaths, deaths_now, on=['location_name'], how='left')
    forecast_inc_confirmed = pd.merge(forecast_inc_confirmed, confirmed_now, on=['location_name'], how='left')
    
    for name,item in zip(['IncDeaths','IncCase'],[forecast_inc_deaths,forecast_inc_confirmed]):
        tmp = item.groupby(['forecast_date',
                            'location_name'])[['value',
                                               'week_label',
                                               'last_label',
                                               'target_end_date']].apply(lambda x:[list(x['value']),
                                                                                   list(x['week_label']),
                                                                                   list(x['last_label']),
                                                                                  [str(item) for item in x['target_end_date']],
                                                                                  ]).reset_index().rename({0:'DUMP'},axis=1)
        dump_dict[name] = dict()
        for item in tmp.values:
            _date,_state,_values = item
            dump_dict[name][_state] = _values

    trend_dict = dict()
    trend = forecast_inc_deaths.groupby('location_name').apply(lambda x:(list(x['value'])[1] + list(x['value'])[0] + 100*2) / (list(x['value'])[0] +  list(x['last_label'])[0] + 100.0*2)).reset_index().rename({0:'value'},axis=1)
    for item in trend.values:
        _state,_values = item
        trend_dict[_state] = _values
        
    trend_inc_dict = dict()
    trend = forecast_inc_confirmed.groupby('location_name').apply(lambda x:(list(x['value'])[1] + list(x['value'])[0] + 10000*2 ) / (list(x['value'])[0] + list(x['last_label'])[0] + 10000*2)).reset_index().rename({0:'value'},axis=1)
    for item in trend.values:
        _state,_values = item
        trend_inc_dict[_state] = _values    
        
    
    return deaths_now, confirmed_now, dump_dict, trend_dict, trend_inc_dict, forecast_inc_confirmed

# %%
deaths, confirmed, location = get_meta_files()

# %%
LOAD_DIR = '../CDC'
FILE_NAME = '2020-11-09-MSRA-DeepST.csv'
deaths_now, confirmed_now, dump_dict, trend_dict, trend_inc_dict, forecast_inc_confirmed = dump_results(FILE_NAME=FILE_NAME)

# %%
forecast_inc_confirmed['last_ratio'] = forecast_inc_confirmed['last_label'] / forecast_inc_confirmed['last2_label']

# %%
forecast_inc_confirmed = forecast_inc_confirmed[['forecast_date','target_end_date','location_name','value']].set_index(['forecast_date',
                                                                                               'target_end_date',
                                                                                               'location_name']).unstack('target_end_date')

# %%
forecast_inc_confirmed.columns = [item for _,item in forecast_inc_confirmed.columns]

# %%
forecast_inc_confirmed = forecast_inc_confirmed.reset_index()

# %%
trend = pd.DataFrame(pd.concat([pd.Series(trend_dict),pd.Series(trend_inc_dict)],axis=1).max(axis=1)).rename({0:'trend'},axis=1)
# trend = pd.DataFrame(pd.Series(trend_dict)).rename({0:'trend'},axis=1)

# %%
trend = pd.merge(trend, confirmed_now.set_index('location_name'), left_index=True, right_index=True).reset_index().rename({'index':'location_name'},axis=1)

# %%
a = pd.merge(forecast_inc_confirmed,trend,on=['location_name'],how='left')

# %%
a.columns = [str(item).split()[0] for item in a.columns]

# %%
use_cols = [item for item in a.columns if item.startswith('2020')]
print(use_cols)
a[use_cols[0]] = (a['last_label'] * a['trend']**1 + a[use_cols[0]])/2.0
a[use_cols[1]] = (a['last_label'] * a['trend']**2 + a[use_cols[1]])/2.0
a[use_cols[2]] = (a['last_label'] * a['trend']**3)
a[use_cols[3]] = (a['last_label'] * a['trend']**4)
# Out:
# ['2020-11-14', '2020-11-21', '2020-11-28', '2020-12-05']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'last_label'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-817-2a5bc611ae39> in <module>
#       1 use_cols = [item for item in a.columns if item.startswith('2020')]
#       2 print(use_cols)
# ----> 3 a[use_cols[0]] = (a['last_label'] * a['trend']**1 + a[use_cols[0]])/2.0
#       4 a[use_cols[1]] = (a['last_label'] * a['trend']**2 + a[use_cols[1]])/2.0
#       5 a[use_cols[2]] = (a['last_label'] * a['trend']**3)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'last_label'

# %%
a[use_cols + ['location_name']].to_csv('../SLT/{}.adj.csv'.format(FILE_NAME.split('.')[0]))

# %%
death_fp = '/home/zhgao/COVID19/COVID-19/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv'
population = pd.read_csv(death_fp)
population= population[['Province_State',
                        'Population']].groupby('Province_State')['Population'].sum().reset_index().rename({'Province_State':'States'},axis=1)
population = population.append({'States':'US','Population':population['Population'].sum()},ignore_index=True)
population.columns = ['location_name','population']

# %%
a = pd.merge(a, population)

# %%
a["Increase Cases Ratio Over The Next 4 Weeks"] = (a['trend']**4.0).map(lambda x:round(x,2))

# %%
a[['forecast_date', 'location_name', '2020-11-14', '2020-11-21',
       '2020-11-28', '2020-12-05','Increase Cases Ratio Over The Next 4 Weeks']].to_csv('../SLT/cases.forecast.11.09.csv')

# %%
use_cols = ['2020-11-14', '2020-11-21', '2020-11-28', '2020-12-05']
for col in use_cols:
    a[col+' (week inc cases/ 100K)'] = (a[col] / a['population'] * 100000).map(lambda x: round(x,2))

# %%
a[['forecast_date', 'location_name','2020-11-14 (week inc cases/ 100K)',
       '2020-11-21 (week inc cases/ 100K)', '2020-11-28 (week inc cases/ 100K)',
       '2020-12-05 (week inc cases/ 100K)']].to_csv('../SLT/cases.100K.forecast.11.09.csv')

# %%
a[['forecast_date', 'location_name', '2020-11-14 (week inc cases/ 100K)',
       '2020-11-21 (week inc cases/ 100K)', '2020-11-28 (week inc cases/ 100K)',
       '2020-12-05 (week inc cases/ 100K)']].\
sort_values('2020-12-05 (week inc cases/ 100K)',ascending=False).style.\
        background_gradient(cmap='Reds',subset=["2020-12-05 (week inc cases/ 100K)"])
# Out:
# <style  type="text/css" >
#     #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow0_col5 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow1_col5 {
#             background-color:  #7c0510;
#             color:  #f1f1f1;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow2_col5 {
#             background-color:  #880811;
#             color:  #f1f1f1;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow3_col5 {
#             background-color:  #d42121;
#             color:  #f1f1f1;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow4_col5 {
#             background-color:  #d82422;
#             color:  #f1f1f1;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow5_col5 {
#             background-color:  #ed392b;
#             color:  #f1f1f1;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow6_col5 {
#             background-color:  #f14432;
#             color:  #f1f1f1;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow7_col5 {
#             background-color:  #f96346;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow8_col5 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow9_col5 {
#             background-color:  #fb6d4d;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow10_col5 {
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow11_col5 {
#             background-color:  #fc8161;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow12_col5 {
#             background-color:  #fc8565;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow13_col5 {
#             background-color:  #fc8969;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow14_col5 {
#             background-color:  #fc8a6a;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow15_col5 {
#             background-color:  #fc8d6d;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow16_col5 {
#             background-color:  #fc9d7f;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow17_col5 {
#             background-color:  #fca183;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow18_col5 {
#             background-color:  #fca98c;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow19_col5 {
#             background-color:  #fcaa8d;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow20_col5 {
#             background-color:  #fcb296;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow21_col5 {
#             background-color:  #fcb499;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow22_col5 {
#             background-color:  #fcbea5;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow23_col5 {
#             background-color:  #fcbfa7;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow24_col5 {
#             background-color:  #fcbfa7;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow25_col5 {
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow26_col5 {
#             background-color:  #fdc5ae;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow27_col5 {
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow28_col5 {
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow29_col5 {
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow30_col5 {
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow31_col5 {
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow32_col5 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow33_col5 {
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow34_col5 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow35_col5 {
#             background-color:  #fedaca;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow36_col5 {
#             background-color:  #fedaca;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow37_col5 {
#             background-color:  #fedaca;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow38_col5 {
#             background-color:  #fedecf;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow39_col5 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow40_col5 {
#             background-color:  #fee1d3;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow41_col5 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow42_col5 {
#             background-color:  #fee6da;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow43_col5 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow44_col5 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow45_col5 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow46_col5 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow47_col5 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow48_col5 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow49_col5 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow50_col5 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aea" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >forecast_date</th>        <th class="col_heading level0 col1" >location_name</th>        <th class="col_heading level0 col2" >2020-11-14 (week inc cases/ 100K)</th>        <th class="col_heading level0 col3" >2020-11-21 (week inc cases/ 100K)</th>        <th class="col_heading level0 col4" >2020-11-28 (week inc cases/ 100K)</th>        <th class="col_heading level0 col5" >2020-12-05 (week inc cases/ 100K)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aealevel0_row0" class="row_heading level0 row0" >33</th>
#                         <td id="T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow0_col0" class="data row0 col0" >2020-11-09</td>
#                         <td id="T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow0_col1" class="data row0 col1" >North Dakota</td>
#                         <td id="T_c8aa2fc8_24ba_11eb_9d3f_6ba735462aearow0_col2" class="data row0 col2" >1303.480000</td>
#                         <td id="T_c8aa2fc8

# %%
a[['forecast_date','location_name','Increase Cases Ratio Over The Next 4 Weeks']].\
sort_values('Increase Cases Ratio Over The Next 4 Weeks',ascending=False).style.\
        background_gradient(cmap='Reds',subset=["Increase Cases Ratio Over The Next 4 Weeks"])

# %%
states = ['Alabama',
 'Alaska',
 'Arizona',
 'Arkansas',
 'California',
 'Colorado',
 'Connecticut',
 'Delaware',
 'Florida',
 'Georgia',
 'Hawaii',
 'Idaho',
 'Illinois',
 'Indiana',
 'Iowa',
 'Kansas',
 'Kentucky',
 'Louisiana',
 'Maine',
 'Maryland',
 'Massachusetts',
 'Michigan',
 'Minnesota',
 'Mississippi',
 'Missouri',
 'Montana',
 'Nebraska',
 'Nevada',
 'New Hampshire',
 'New Jersey',
 'New Mexico',
 'New York',
 'North Carolina',
 'North Dakota',
 'Ohio',
 'Oklahoma',
 'Oregon',
 'Pennsylvania',
 'Rhode Island',
 'South Carolina',
 'South Dakota',
 'Tennessee',
 'Texas',
 'Utah',
 'Vermont',
 'Virginia',
 'Washington',
 'West Virginia',
 'Wisconsin',
 'Wyoming']

# %%
results = []
for fname in [
             '2020-10-19-MSRA-DeepST.adj.csv']:
    results.append(pd.read_csv('../SLT/{}'.format(fname),index_col=0))

# %%
results = pd.concat(results,axis=1)

# %%
results.columns[:-2]
# Out:
# Index(['2020-10-24', '2020-10-31', '2020-11-07'], dtype='object')

# %%
y_true = confirmed[confirmed.target_end_date.isin(results.columns[:-2])][['location_name',
                                                                         'target_end_date',
                                                                         'week_label']]

# %%
results = results.set_index('location_name').stack().reset_index().rename({'level_1':'target_end_date',
                                                                 0:'pred'},axis=1)
results = results[results.target_end_date!='2020-11-14']

# %%
y_true = y_true[y_true.location_name.isin(states)].sort_values(['location_name','target_end_date'])
results = results[results.location_name.isin(states)].sort_values(['location_name','target_end_date'])

# %%
results['mae'] = np.abs(1 - results['pred'].values / y_true['week_label'].values)

# %%
results.groupby('target_end_date')['mae'].mean()
# Out:
# target_end_date
# 2020-10-24    0.127222
# 2020-10-31    0.235990
# 2020-11-07    0.376998
# Name: mae, dtype: float64

# %%
target_list_1 = [
   '1 wk ahead cum death', '2 wk ahead cum death',
   '3 wk ahead cum death', '4 wk ahead cum death',
   '1 wk ahead inc death', '2 wk ahead inc death',
   '3 wk ahead inc death', '4 wk ahead inc death',
#    '1 wk ahead inc case', '2 wk ahead inc case',
#    '3 wk ahead inc case', '4 wk ahead inc case'
    ]
target_list_2 = [
#    '1 wk ahead cum death', '2 wk ahead cum death',
#    '3 wk ahead cum death', '4 wk ahead cum death',
#    '1 wk ahead inc death', '2 wk ahead inc death',
#    '3 wk ahead inc death', '4 wk ahead inc death',
   '1 wk ahead inc case', '2 wk ahead inc case',
   '3 wk ahead inc case', '4 wk ahead inc case']
state_list = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
   'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
   'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
   'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
   'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
   'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
   'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
   'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
   'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
   'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming', 'US']

prophet = pd.read_csv('../SLT/prophet.forecast.csv')
prophet.columns = ['NAN','target_end_date','yhat','location_name','predict_week']
prophet = prophet[['target_end_date','location_name','predict_week']]
deep = pd.read_csv('../CDC/2020-11-09-MSRA-DeepST.csv')
deep = pd.merge(deep, location[['location','location_name']], on=['location'], how='left')

# %%
us = prophet.groupby('target_end_date')['predict_week'].sum().reset_index()
us['location_name'] = 'US'
prophet = pd.concat([prophet,us]).reset_index(drop=True)

# %%
deep_deaths = deep[deep.target.isin(target_list_1)][deep.type=='point']
deep = deep[deep.target.isin(target_list_2)][deep.type=='point']
# Out:
# /home/zhgao/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /home/zhgao/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
en = pd.merge(deep,prophet[['target_end_date','location_name','predict_week']],on=['target_end_date','location_name'],how='left')

# %%
en['forecasting'] = en['predict_week'].map(abs)*0.2 + en['value']*0.8

# %%
en = pd.merge(en,population,on=['location_name'],how='left')

# %%
en = en.rename({'value':'DeepST_predict',
           'predict_week':'Prophet_predict',
           'forecasting':'Ensemble_predict'},
              axis=1)

# %%
en['DeepST_predict_perday_100k'] = (en['DeepST_predict'] / en['population'] * 100000/ 7).map(lambda x:round(x,2))
en['Prophet_predict_perday_100k'] = (en['Prophet_predict'] / en['population'] * 100000/ 7).map(lambda x:round(x,2))
en['Ensemble_predict_perday_100k'] = (en['Ensemble_predict'] / en['population'] * 100000/7).map(lambda x:round(x,2))

# %%
en['DeepST_ratio'] = (en['DeepST_predict'] / en['week_label']).map(lambda x:round(x,2))
en['Prophet_ratio'] = (en['Prophet_predict'] / en['week_label']).map(lambda x:round(x,2))
en['Ensemble_ratio'] = (en['Ensemble_predict'] / en['week_label']).map(lambda x:round(x,2))

# %%
en[['location_name','forecast_date', 'target', 'target_end_date','DeepST_predict','Prophet_predict','Ensemble_predict',
   'DeepST_ratio','Prophet_ratio','Ensemble_ratio']].to_csv('../SLT/cases.forecast.11.09.csv')

# %%
en[['location_name','forecast_date', 'target', 'target_end_date','DeepST_predict_perday_100k','Prophet_predict_perday_100k','Ensemble_predict_perday_100k']].to_csv('../SLT/cases.100K.forecast.11.09.csv')

# %%
lastweek = confirmed[confirmed.target_end_date=='2020-11-07'][['location_name','week_label']]

# %%
en = pd.merge(en,lastweek,on=['location_name'],how='left')

# %%
tmp = en[['location_name','forecast_date', 'target', 'target_end_date','Ensemble_ratio']].rename({'Ensemble_ratio':
                                                                                                  'Increase Cases Ratio Over The Next 4 Weeks'},axis=1)

# %%
tmp[tmp.target_end_date=='2020-12-05'].sort_values('Increase Cases Ratio Over The Next 4 Weeks',ascending=False).style.background_gradient(cmap='Reds',subset=["Increase Cases Ratio Over The Next 4 Weeks"])
# Out:
# <style  type="text/css" >
#     #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow0_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow1_col4 {
#             background-color:  #f24734;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow2_col4 {
#             background-color:  #f96346;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow3_col4 {
#             background-color:  #fb6c4c;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow4_col4 {
#             background-color:  #fb7353;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow5_col4 {
#             background-color:  #fb7858;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow6_col4 {
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow7_col4 {
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow8_col4 {
#             background-color:  #fc8060;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow9_col4 {
#             background-color:  #fc8060;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow10_col4 {
#             background-color:  #fc8161;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow11_col4 {
#             background-color:  #fc8565;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow12_col4 {
#             background-color:  #fc8666;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow13_col4 {
#             background-color:  #fc8767;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow14_col4 {
#             background-color:  #fc8969;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow15_col4 {
#             background-color:  #fc8969;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow16_col4 {
#             background-color:  #fc8969;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow17_col4 {
#             background-color:  #fc8d6d;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow18_col4 {
#             background-color:  #fc8e6e;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow19_col4 {
#             background-color:  #fc8f6f;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow20_col4 {
#             background-color:  #fc9070;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow21_col4 {
#             background-color:  #fc9272;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow22_col4 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow23_col4 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow24_col4 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow25_col4 {
#             background-color:  #fc9576;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow26_col4 {
#             background-color:  #fc9777;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow27_col4 {
#             background-color:  #fc9777;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow28_col4 {
#             background-color:  #fc9879;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow29_col4 {
#             background-color:  #fc9c7d;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow30_col4 {
#             background-color:  #fc9d7f;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow31_col4 {
#             background-color:  #fca082;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow32_col4 {
#             background-color:  #fca082;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow33_col4 {
#             background-color:  #fca183;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow34_col4 {
#             background-color:  #fca486;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow35_col4 {
#             background-color:  #fca588;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow36_col4 {
#             background-color:  #fca588;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow37_col4 {
#             background-color:  #fca689;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow38_col4 {
#             background-color:  #fca98c;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow39_col4 {
#             background-color:  #fcab8f;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow40_col4 {
#             background-color:  #fcae92;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow41_col4 {
#             background-color:  #fcb095;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow42_col4 {
#             background-color:  #fcb69b;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow43_col4 {
#             background-color:  #fcb79c;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow44_col4 {
#             background-color:  #fcb89e;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow45_col4 {
#             background-color:  #fcbca2;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow46_col4 {
#             background-color:  #fcbda4;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow47_col4 {
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow48_col4 {
#             background-color:  #fdc5ae;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow49_col4 {
#             background-color:  #fdcbb6;
#             color:  #000000;
#         }    #T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow50_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_cab1ee24_24f5_11eb_9d3f_6ba735462aea" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >location_name</th>        <th class="col_heading level0 col1" >forecast_date</th>        <th class="col_heading level0 col2" >target</th>        <th class="col_heading level0 col3" >target_end_date</th>        <th class="col_heading level0 col4" >Increase Cases Ratio Over The Next 4 Weeks</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cab1ee24_24f5_11eb_9d3f_6ba735462aealevel0_row0" class="row_heading level0 row0" >197</th>
#                         <td id="T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow0_col0" class="data row0 col0" >Vermont</td>
#                         <td id="T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow0_col1" class="data row0 col1" >2020-11-09</td>
#                         <td id="T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow0_col2" class="data row0 col2" >4 wk ahead inc case</td>
#                         <td id="T_cab1ee24_24f5_11eb_9d3f_6ba735462aearow0_col3" class="data row0 col3" >2020-12-05</td>
#                         <td id="T_ca

# %%
tmp = en[['location_name','forecast_date', 'target', 'target_end_date','Ensemble_predict_perday_100k']].rename({'Ensemble_predict_perday_100k':
                                                                                                  'Day inc cases / 100K'},axis=1)

# %%
tmp[tmp.target_end_date=='2020-12-05'].sort_values('Day inc cases / 100K',ascending=False).style.background_gradient(cmap='Reds',subset=["Day inc cases / 100K"])
# Out:
# <style  type="text/css" >
#     #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow0_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow1_col4 {
#             background-color:  #bb141a;
#             color:  #f1f1f1;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow2_col4 {
#             background-color:  #e53228;
#             color:  #f1f1f1;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow3_col4 {
#             background-color:  #fa6849;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow4_col4 {
#             background-color:  #fb6d4d;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow5_col4 {
#             background-color:  #fb7353;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow6_col4 {
#             background-color:  #fb7656;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow7_col4 {
#             background-color:  #fb7a5a;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow8_col4 {
#             background-color:  #fc8969;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow9_col4 {
#             background-color:  #fc8d6d;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow10_col4 {
#             background-color:  #fc9879;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow11_col4 {
#             background-color:  #fc9d7f;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow12_col4 {
#             background-color:  #fc9d7f;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow13_col4 {
#             background-color:  #fca689;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow14_col4 {
#             background-color:  #fcaa8d;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow15_col4 {
#             background-color:  #fcb095;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow16_col4 {
#             background-color:  #fcb398;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow17_col4 {
#             background-color:  #fcbfa7;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow18_col4 {
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow19_col4 {
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow20_col4 {
#             background-color:  #fdc9b3;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow21_col4 {
#             background-color:  #fdcbb6;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow22_col4 {
#             background-color:  #fdccb8;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow23_col4 {
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow24_col4 {
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow25_col4 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow26_col4 {
#             background-color:  #fedecf;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow27_col4 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow28_col4 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow29_col4 {
#             background-color:  #fee1d3;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow30_col4 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow31_col4 {
#             background-color:  #fee3d6;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow32_col4 {
#             background-color:  #fee3d7;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow33_col4 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow34_col4 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow35_col4 {
#             background-color:  #fee7db;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow36_col4 {
#             background-color:  #fee7db;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow37_col4 {
#             background-color:  #fee7dc;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow38_col4 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow39_col4 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow40_col4 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow41_col4 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow42_col4 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow43_col4 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow44_col4 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow45_col4 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow46_col4 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow47_col4 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow48_col4 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow49_col4 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow50_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_cb65fd88_24f5_11eb_9d3f_6ba735462aea" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >location_name</th>        <th class="col_heading level0 col1" >forecast_date</th>        <th class="col_heading level0 col2" >target</th>        <th class="col_heading level0 col3" >target_end_date</th>        <th class="col_heading level0 col4" >Day inc cases / 100K</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cb65fd88_24f5_11eb_9d3f_6ba735462aealevel0_row0" class="row_heading level0 row0" >186</th>
#                         <td id="T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow0_col0" class="data row0 col0" >North Dakota</td>
#                         <td id="T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow0_col1" class="data row0 col1" >2020-11-09</td>
#                         <td id="T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow0_col2" class="data row0 col2" >4 wk ahead inc case</td>
#                         <td id="T_cb65fd88_24f5_11eb_9d3f_6ba735462aearow0_col3" class="data row0 col3" >2020-12-05</td>
#                         <td id="T_cb65fd88_24f5_11eb_

# %%
tmp[tmp.target_end_date=='2020-12-05']
# Out:
#       location_name forecast_date               target target_end_date  \
# 153         Alabama    2020-11-09  4 wk ahead inc case      2020-12-05
# 154          Alaska    2020-11-09  4 wk ahead inc case      2020-12-05
# 155         Arizona    2020-11-09  4 wk ahead inc case      2020-12-05
# 156        Arkansas    2020-11-09  4 wk ahead inc case      2020-12-05
# 157      California    2020-11-09  4 wk ahead inc case      2020-12-05
# 158        Colorado    2020-11-09  4 wk ahead inc case      2020-12-05
# 159     Connecticut    2020-11-09  4 wk ahead inc case      2020-12-05
# 160        Delaware    2020-11-09  4 wk ahead inc case      2020-12-05
# 161         Florida    2020-11-09  4 wk ahead inc case      2020-12-05
# 162         Georgia    2020-11-09  4 wk ahead inc case      2020-12-05
# 163          Hawaii    2020-11-09  4 wk ahead inc case      2020-12-05
# 164           Idaho    2020-11-09  4 wk ahead inc case      2020-12-05
# 165        Illinois    2020-11-09  4 wk ahead inc case      2020-12-05
# 166         Indiana    2020-11-09  4 wk ahead inc case      2020-12-05
# 167            Iowa    2020-11-09  4 wk ahead inc case      2020-12-05
# 168          Kansas    2020-11-09  4 wk ahead inc case      2020-12-05
# 169        Kentucky    2020-11-09  4 wk ahead inc case      2020-12-05
# 170       Louisiana    2020-11-09  4 wk ahead inc case      2020-12-05
# 171           Maine    2020-11-09  4 wk ahead inc case      2020-12-05
# 172        Maryland    2020-11-09  4 wk ahead inc case      2020-12-05
# 173   Massachusetts    2020-11-09  4 wk ahead inc case      2020-12-05
# 174        Michigan    2020-11-09  4 wk ahead inc case      2020-12-05
# 175       Minnesota    2020-11-09  4 wk ahead inc case      2020-12-05
# 176     Mississippi    2020-11-09  4 wk ahead inc case      2020-12-05
# 177        Missouri    2020-11-09  4 wk ahead inc case      2020-12-05
# 178         Montana    2020-11-09  4 wk ahead inc case      2020-12-05
# 179        Nebraska    2020-11-09  4 wk ahead inc case      2020-12-05
# 180          Nevada    2020-11-09  4 wk ahead inc case      2020-12-05
# 181   New Hampshire    2020-11-09  4 wk ahead inc case      2020-12-05
# 182      New Jersey    2020-11-09  4 wk ahead inc case      2020-12-05
# 183      New Mexico    2020-11-09  4 wk ahead inc case      2020-12-05
# 184        New York    2020-11-09  4 wk ahead inc case      2020-12-05
# 185  North Carolina    2020-11-09  4 wk ahead inc case      2020-12-05
# 186    North Dakota    2020-11-09  4 wk ahead inc case      2020-12-05
# 187            Ohio    2020-11-09  4 wk ahead inc case      2020-12-05
# 188        Oklahoma    2020-11-09  4 wk ahead inc case      2020-12-05
# 189          Oregon    2020-11-09  4 wk ahead inc case      2020-12-05
# 190    Pennsylvania    2020-11-09  4 wk ahead inc case      2020-12-05
# 191    Rhode Island    2020-11-09  4 wk ahead inc case      2020-12-05
# 192  South Carolina    2020-11-09  4 wk ahead inc case      2020-12-05
# 193    South Dakota    2020-11-09  4 wk ahead inc case      2020-12-05
# 194       Tennessee    2020-11-09  4 wk ahead inc case      2020-12-05
# 195           Texas    2020-11-09  4 wk ahead inc case      2020-12-05
# 196            Utah    2020-11-09  4 wk ahead inc case      2020-12-05
# 197         Vermont    2020-11-09  4 wk ahead inc case      2020-12-05
# 198        Virginia    2020-11-09  4 wk ahead inc case      2020-12-05
# 199      Washington    2020-11-09  4 wk ahead inc case      2020-12-05
# 200   West Virginia    2020-11-09  4 wk ahead inc case      2020-12-05
# 201       Wisconsin    2020-11-09  4 wk ahead inc case      2020-12-05
# 202         Wyoming    2020-11-09  4 wk ahead inc case      2020-12-05
# 203              US    2020-11-09  4 wk ahead inc case      2020-12-05
#
#      Ensemble_predict_perday_100k
# 153                         43.25
# 154                        104.14
# 155                         50.84
# 156                         79.98
# 157                         19.35
# 158                        107.64
# 159                         16.55
# 160                         44.86
# 161                         41.25
# 162                         94.80
# 163                         18.95
# 164                         99.80
# 165                        159.85
# 166                        127.95
# 167                        276.58
# 168                        160.11
# 169                         53.80
# 170                         24.86
# 171                         23.65
# 172                         36.31
# 173                         47.34
# 174                         51.32
# 175                        186.23
# 176                         42.89
# 177                        119.40
# 178                        114.77
# 179                        190.45
# 180                         90.98
# 181                         31.46
# 182                         45.66
# 183                         98.42
# 184                         29.59
# 185                         30.26
# 186                        333.40
# 187                         80.60
# 188                        113.29
# 189                         38.04
# 190                         34.11
# 191                         32.22
# 192                         32.05
# 193                        227.29
# 194                         74.61
# 195                         35.13
# 196                        153.87
# 197                         10.84
# 198                         25.87
# 199                         39.40
# 200                         52.52
# 201                        159.15
# 202                        157.36
# 203                         62.24
